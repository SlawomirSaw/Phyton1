# %%
import TransparencyEntsoeEUData
import matplotlib as mpl
mpl.rcParams['axes.grid'] = True
mpl.rcParams['grid.linestyle'] = '--'
mpl.rcParams['grid.linewidth'] = 0.5
mpl.rcParams['axes.grid.axis'] ='both'
mpl.rcParams['axes.grid.which'] ='both'

TransparencyEntsoeEUData.getTransparencyEntsoeEUData()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2976 entries, 2026-05-01 00:00:00+02:00 to 2026-05-31 23:45:00+02:00
# Freq: 15min
# Data columns (total 14 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   (Biomass, Actual Aggregated)                          2976 non-null   float64
#  1   (Fossil Brown coal/Lignite, Actual Aggregated)        2976 non-null   float64
#  2   (Fossil Coal-derived gas, Actual Aggregated)          2976 non-null   float64
#  3   (Fossil Gas, Actual Aggregated)                       2976 non-null   float64
#  4   (Fossil Hard coal, Actual Aggregated)                 2976 non-null   float64
#  5   (Fossil Oil, Actual Aggregated)                       2976 non-null   float64
#  6   (Hydro Pumped Storage, Actual Aggregated)             2976 non-null   float64
#  7   (Hydro Pumped Storage, Actual Consumption)            2976 non-null   float64
#  8   (Hydro Run-of-river and poundage, Actual Aggregated)  2976 non-null   float64
#  9   (Hydro Water Reservoir, Actual Aggregated)            2976 non-null   float64
#  10  (Other, Actual Aggregated)                            2976 non-null   float64
#  11  (Other renewable, Actual Aggregated)                  2976 non-null   float64
#  12  (Solar, Actual Aggregated)                            2976 non-null   float64
#  13  (Wind Onshore, Actual Aggregated)                     2976 non-null   float64
# dtypes: float64(14)
# memory usage: 348.8 KB
